# %%
import pandas as pd
from sqlalchemy import create_engine
from config import password

# %%
#import csv data
airbnba = "./listings .csv" 
airbnba_df = pd.read_csv(airbnba)
airbnba_df.head()
# Out:
#      id                                       name  host_id  host_name  \
# 0  1078          *UT/Hyde Park Craftsman Apartment  4635658      Tracy
# 1  2265            Zen-East in the Heart of Austin     2466      Paddy
# 2  5245        Green, Colorful, Clean &  Cozy home     2466      Paddy
# 3  5456  Walk to 6th, Rainey St and Convention Ctr     8028     Sylvia
# 4  5769                             NW Austin Room     8186  Elizabeth
#
#    neighbourhood_group  neighbourhood  latitude  longitude        room_type  \
# 0                  NaN          78705  30.30123  -97.73674  Entire home/apt
# 1                  NaN          78702  30.27750  -97.71398  Entire home/apt
# 2                  NaN          78702  30.27577  -97.71379     Private room
# 3                  NaN          78702  30.26112  -97.73448  Entire home/apt
# 4                  NaN          78729  30.45596  -97.78370     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
# delete the column neighbourhood_group
del airbnba_df['neighbourhood_group']
del airbnba_df['name']
airbnba_df.head()
# Out:
#      id  host_id  host_name  neighbourhood  latitude  longitude  \
# 0  1078  4635658      Tracy          78705  30.30123  -97.73674
# 1  2265     2466      Paddy          78702  30.27750  -97.71398
# 2  5245     2466      Paddy          78702  30.27577  -97.71379
# 3  5456     8028     Sylvia          78702  30.26112  -97.73448
# 4  5769     8186  Elizabeth          78729  30.45596  -97.78370
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     85               2                221  2019-04-28
# 1  Entire home/apt    225              28                 24  2019-03-16
# 2     Private room    100              28                  9  2018-03-14
# 3  Entire home/apt     95               2                481  2019-04-23
# 4     Private room     40               1                246  2019-04-28
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %%
total_rows = airbnba_df.count
total_rows
# Out:
# <bound method DataFrame.count of              id    host_id          host_name  neighbourhood  latitude  \
# 0          1078    4635658              Tracy          78705  30.30123
# 1          2265       2466              Paddy          78702  30.27750
# 2          5245       2466              Paddy          78702  30.27577
# 3          5456       8028             Sylvia          78702  30.26112
# 4          5769       8186          Elizabeth          78729  30.45596
# 5          6413      13879               Todd          78704  30.24829
# 6          6448      14156                Amy          78704  30.26027
# 7          8502      25298              Karen          78741  30.23616
# 8         14765      57982             Charla          78704  30.25012
# 9         14913      58635             Steven          78748  30.15645
# 10        21126      80406               Dani          78704  30.24503
# 11        21145      80511              April          78705  30.29422
# ...

# %%
#Keep only the rows without non-NA values
airbnba_df.dropna(inplace=True)
airbnba_df.head()
# Out:
#      id  host_id  host_name  neighbourhood  latitude  longitude  \
# 0  1078  4635658      Tracy          78705  30.30123  -97.73674
# 1  2265     2466      Paddy          78702  30.27750  -97.71398
# 2  5245     2466      Paddy          78702  30.27577  -97.71379
# 3  5456     8028     Sylvia          78702  30.26112  -97.73448
# 4  5769     8186  Elizabeth          78729  30.45596  -97.78370
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     85               2                221  2019-04-28
# 1  Entire home/apt    225              28                 24  2019-03-16
# 2     Private room    100              28                  9  2018-03-14
# 3  Entire home/apt     95               2                481  2019-04-23
# 4     Private room     40               1                246  2019-04-28
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %%
total_rows = airbnba_df.count
total_rows
# Out:
# <bound method DataFrame.count of              id    host_id          host_name  neighbourhood  latitude  \
# 0          1078    4635658              Tracy          78705  30.30123
# 1          2265       2466              Paddy          78702  30.27750
# 2          5245       2466              Paddy          78702  30.27577
# 3          5456       8028             Sylvia          78702  30.26112
# 4          5769       8186          Elizabeth          78729  30.45596
# 5          6413      13879               Todd          78704  30.24829
# 6          6448      14156                Amy          78704  30.26027
# 7          8502      25298              Karen          78741  30.23616
# 8         14765      57982             Charla          78704  30.25012
# 9         14913      58635             Steven          78748  30.15645
# 10        21126      80406               Dani          78704  30.24503
# 11        21145      80511              April          78705  30.29422
# ...

# %%
# set index for the dataframe
finalairbnba_df= airbnba_df .reset_index()
finalairbnba_df.head(10)
finalairbnba_df.to_csv("cleaned_listings.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-36-3b9e5bbd7932> in <module>
#       2 finalairbnba_df= airbnba_df .reset_index()
#       3 finalairbnba_df.head(10)
# ----> 4 finalairbnba_df.to_csv("cleaned_listings.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
# ...

# %%
#Connect to local databaseT
rds_connection_string = "root:Tulasi1432@localhost:3306/airbnbaustin_db"

# %%
engine = create_engine(f'mysql+pymysql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# ...

# %%
finalairbnba_df.to_sql(name='finalairbnba_data', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     399         if not self._use_threadlocal:
# --> 400             return _ConnectionFairy._checkout(self)
#     401
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
#     530         try:
#
# ...
